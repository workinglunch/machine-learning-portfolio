# %%
print("hello Rory")
# Out:
# hello Rory

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
print("ML environment is ready!")import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
print("ML environment is ready!")
# Out:
#   Cell In[2], line 9
#     print("ML environment is ready!")import numpy as np
#                                      ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
print("ML environment is ready!")
# Out:
# NumPy: 2.5.2
# Pandas: 3.0.5
# Scikit-learn: 1.9.0
# ML environment is ready!

# %%
name = "Rory"
Age = 53
course = "machine learning"

Print(name)
Print(age)
Print(course)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 name = "Rory"
#       2 Age = 53
#       3 course = "machine learning"
#       4
# ----> 5 Print(name)
#       6 Print(age)
#       7 Print(course)
#
# NameError: name 'Print' is not defined

# %%
name = "Rory"
age = 53
course = "Machine Learning"

print(name)
print(age)
print(course)
# Out:
# Rory
# 53
# Machine Learning

# %%
weight = 103
height = 1.93

bmi = weight / (height * height)
print(bmi)
# Out:
# 27.65174904024269

# %%
name = "Rory"
print(f"{name}'s BMI is {bmi:.2f}")
# Out:
# Rory's BMI is 27.65

# %%
name = "Rory"
print(f"{name} Weight is {weight}KG")
# Out:
# Rory Weight is 103KG
